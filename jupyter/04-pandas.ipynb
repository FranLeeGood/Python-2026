# %%
#Inportando librerias

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
datos = pd.read_csv("data/games.csv", index_col="Id")
datos.head()
# Out:
#                                       Title  Release Date  \
# Id
# 0                                Elden Ring  Feb 25, 2022
# 1                                     Hades  Dec 10, 2019
# 2   The Legend of Zelda: Breath of the Wild  Mar 03, 2017
# 3                                 Undertale  Sep 15, 2015
# 4                             Hollow Knight  Feb 24, 2017
#
#                                                  Team  Rating Times Listed  \
# Id
# 0      ['Bandai Namco Entertainment', 'FromSoftware']     4.5         3.9K
# 1                                ['Supergiant Games']     4.3         2.9K
# 2   ['Nintendo', 'Nintendo EPD Production Group No...     4.4         4.3K
# 3                                  ['tobyfox', '8-4']     4.2         3.5K
# 4                                     ['Team Cherry']     4.4           3K
#
#    Number of Reviews                                             Genres  \
# Id
# 0               3.9K                               ['Adventure', 'RPG']
# ...

# %%
type(datos)
# Out:
# pandas.DataFrame

# %%
print(f"cantidad de filas: {datos.shape}")
# Out:
# cantidad de filas: (1512, 13)

# %%
datos.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1512 entries, 0 to 1511
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Title              1512 non-null   str
#  1   Release Date       1512 non-null   str
#  2   Team               1511 non-null   str
#  3   Rating             1499 non-null   float64
#  4   Times Listed       1512 non-null   str
#  5   Number of Reviews  1512 non-null   str
#  6   Genres             1512 non-null   str
#  7   Summary            1511 non-null   str
#  8   Reviews            1512 non-null   str
#  9   Plays              1512 non-null   str
#  10  Playing            1512 non-null   str
#  11  Backlogs           1512 non-null   str
#  12  Wishlist           1512 non-null   str
# dtypes: float64(1), str(12)
# memory usage: 153.7 KB

# %%
datos.describe()
# Out:
#             Rating
# count  1499.000000
# mean      3.719346
# std       0.532608
# min       0.700000
# 25%       3.400000
# 50%       3.800000
# 75%       4.100000
# max       4.800000

# %%
datos.isnull()
# Out:
#       Title  Release Date   Team  Rating  Times Listed  Number of Reviews  \
# Id
# 0     False         False  False   False         False              False
# 1     False         False  False   False         False              False
# 2     False         False  False   False         False              False
# 3     False         False  False   False         False              False
# 4     False         False  False   False         False              False
# ...     ...           ...    ...     ...           ...                ...
# 1507  False         False  False   False         False              False
# 1508  False         False  False   False         False              False
# 1509  False         False  False   False         False              False
# 1510  False         False  False   False         False              False
# 1511  False         False  False   False         False              False
#
#       Genres  Summary  Reviews  Plays  Playing  Backlogs  Wishlist
# Id
# ...

# %%
columnas_nulas = datos.isnull().any()
columnas_nulas
# Out:
# Title                False
# Release Date         False
# Team                  True
# Rating                True
# Times Listed         False
# Number of Reviews    False
# Genres               False
# Summary               True
# Reviews              False
# Plays                False
# Playing              False
# Backlogs             False
# Wishlist             False
# dtype: bool

# %%
filas_nulas = datos[datos.isnull().any(axis=1)]
filas_nulas
# Out:
#                                                   Title     Release Date  \
# Id
# 587                                   Final Fantasy XVI     Jun 22, 2023
# 649                                   Death Stranding 2  releases on TBD
# 713                           Final Fantasy VII Rebirth     Dec 31, 2023
# 719                                           Lies of P     Aug 01, 2023
# 726                                               Judas     Mar 31, 2025
# 746   Like a Dragon Gaiden: The Man Who Erased His Name     Dec 31, 2023
# 972           The Legend of Zelda: Tears of the Kingdom     May 12, 2023
# 1130                           Star Wars Jedi: Survivor     Apr 28, 2023
# 1160            We Love Katamari Reroll + Royal Reverie     Jun 02, 2023
# 1202                                         Earthblade     Dec 31, 2024
# 1245                               NEET Girl Date Night     Oct 21, 2022
# 1305                                          Diablo IV     Jun 06, 2023
# ...

# %% [markdown]
# #### **eliminar los dato nulos del dataset**

# %%
datos_sin_nulos = datos.dropna() #se eliminan 14 filas
datos_sin_nulos
# Out:
#                                         Title  Release Date  \
# Id
# 0                                  Elden Ring  Feb 25, 2022
# 1                                       Hades  Dec 10, 2019
# 2     The Legend of Zelda: Breath of the Wild  Mar 03, 2017
# 3                                   Undertale  Sep 15, 2015
# 4                               Hollow Knight  Feb 24, 2017
# ...                                       ...           ...
# 1507             Back to the Future: The Game  Dec 22, 2010
# 1508                        Team Sonic Racing  May 21, 2019
# 1509                           Dragon's Dogma  May 22, 2012
# 1510                          Baldur's Gate 3  Oct 06, 2020
# 1511                 The LEGO Movie Videogame  Feb 04, 2014
#
#                                                    Team  Rating Times Listed  \
# Id
# 0        ['Bandai Namco Entertainment', 'FromSoftware']     4.5         3.9K
# 1                                  ['Supergiant Games']     4.3         2.9K
# ...

# %%
# funcion que filtra por genero RPG
def filtro_rpg(genres):
    return "RPG" in genres

# aplicar un filtro para  consultar y llamar a la funcion filtros_rpg
datosRPG = datos_sin_nulos[datos_sin_nulos["Genres"].apply(filtro_rpg)]

nombresRPG = datosRPG[["Title","Rating"]]
nombresRPG.head(20)
# Out:
#                                       Title  Rating
# Id
# 0                                Elden Ring     4.5
# 1                                     Hades     4.3
# 2   The Legend of Zelda: Breath of the Wild     4.4
# 3                                 Undertale     4.2
# 6                                     Omori     4.2
# 9                            NieR: Automata     4.3
# 10                          Persona 5 Royal     4.4
# 12                               God of War     4.2
# 14                               Bloodborne     4.5
# 16                                 Yakuza 0     4.4
# 17                    Red Dead Redemption 2     4.4
# 20                  Pokémon Legends: Arceus     3.7
# 24                           Cyberpunk 2077     3.3
# 26                   Xenoblade Chronicles 3     4.4
# 28             Disco Elysium: The Final Cut     4.6
# 30                           Dark Souls III     4.2
# 31      NieR Replicant ver.1.22474487139...     4.2
# ...

# %%
nombresRPG.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 516 entries, 0 to 1510
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Title   516 non-null    str
#  1   Rating  516 non-null    float64
# dtypes: float64(1), str(1)
# memory usage: 12.1 KB

# %%
graficosRPG = nombresRPG.head(10) # graficosRPG solo tiene los primeros 10 videojuegos RPG

graficosRPG
# Out:
#                                       Title  Rating
# Id
# 0                                Elden Ring     4.5
# 1                                     Hades     4.3
# 2   The Legend of Zelda: Breath of the Wild     4.4
# 3                                 Undertale     4.2
# 6                                     Omori     4.2
# 9                            NieR: Automata     4.3
# 10                          Persona 5 Royal     4.4
# 12                               God of War     4.2
# 14                               Bloodborne     4.5
# 16                                 Yakuza 0     4.4

# %%
graficosRPG.drop(["Title"], axis=1)["Rating"].plot(kind="bar")
# Out:
# <Axes: xlabel='Id'>

# %%
graficosRPG = nombresRPG.head(10)

graficosRPG.set_index("Title", inplace=True)
graficosRPG["Rating"].plot(kind="bar")
# Out:
# <Axes: xlabel='Title'>

# %%
graficosRPG = nombresRPG.head(10)

graficosRPG.set_index("Title", inplace=True)

graph = graficosRPG["Rating"].plot(kind="bar")


for i, rating in enumerate(graficosRPG["Rating"]):
    graph.annotate(str(rating), xy=(i, rating), ha="center", va="bottom")

# %%
promedioRPG = datosRPG[["Rating"]]
promRPG = promedioRPG.mean()

# %%
# funcion que filtra por genero RPG
def filtro_indie(genres):
    return "Indie" in genres

# aplicar un filtro para  consultar y llamar a la funcion filtros_rpg
datosIndie = datos_sin_nulos[datos_sin_nulos["Genres"].apply(filtro_indie)]
datosIndie
# Out:
#                                        Title  Release Date  \
# Id
# 1                                      Hades  Dec 10, 2019
# 3                                  Undertale  Sep 15, 2015
# 4                              Hollow Knight  Feb 24, 2017
# 6                                      Omori  Dec 25, 2020
# 8                                   Among Us  Jun 15, 2018
# ...                                      ...           ...
# 1467                               La-Mulana  Jul 13, 2012
# 1480                  The Jackbox Party Pack  Nov 18, 2014
# 1485  Ruined King: A League of Legends Story  Nov 16, 2021
# 1487                         Lisa the Joyful  Aug 24, 2015
# 1500                       Children of Morta  Sep 03, 2019
#
#                                       Team  Rating Times Listed  \
# Id
# 1                     ['Supergiant Games']     4.3         2.9K
# 3                       ['tobyfox', '8-4']     4.2         3.5K
# ...

# %%
promedioIndie = datosIndie[["Rating"]]
promedioInd= promedioIndie.mean()
promedioInd
# Out:
# Rating    3.70318
# dtype: float64

# %%
taset_promedios = pd.DataFrame({"genero":["RPG", "indie"], "promedio": [promeRPG, promInd] })
data_promedios
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 taset_promedios = pd.DataFrame({"genero":["RPG", "indie"], "promedio": [promeRPG, promInd] })
#       2 data_promedios
#
# NameError: name 'promeRPG' is not defined
